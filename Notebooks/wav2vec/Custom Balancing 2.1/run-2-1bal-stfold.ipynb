# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from pathlib import Path
import os

from sklearn.metrics import classification_report
import tensorflow.keras.backend as K

from tensorflow.keras import layers
# Out:
# WARNING: Logging before InitGoogle() is written to STDERR
# E0000 00:00:1753708701.855933      10 common_lib.cc:612] Could not set metric server port: INVALID_ARGUMENT: Could not find SliceBuilder port 8471 in any of the 0 ports provided in `tpu_process_addresses`="local"
# === Source Location Trace: ===
# learning/45eac/tfrc/runtime/common_lib.cc:230

# %%
# Config 
INPUT_DIR = Path("/kaggle/working/output_wav2vec_custom_augmented")
OUTPUT_DIR = Path("./out_stFold")
OUTPUT_DIR.mkdir(exist_ok=True)

MAX_SEQ_LEN = 150
EMBEDDING_DIM = 768
LABEL_COLS = ['Prolongation', 'Block', 'SoundRep', 'WordRep', 'Interjection']
NUM_CLASSES = len(LABEL_COLS)

BATCH_SIZE_PER_REPLICA = 32
EPOCHS = 400
LEARNING_RATE = 1e-5
THRESHOLD = 0.5

TRAIN_DATA_PATH = INPUT_DIR / "train_data.npz"
VAL_DATA_PATH = INPUT_DIR / "val_data.npz"
TEST_DATA_PATH = INPUT_DIR / "test_data.npz"
BEST_MODEL_PATH = OUTPUT_DIR / "run3_simp.keras"

# %%
print("--- Initializing TPU Strategy ---")

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect(tpu='local')
    # tf.config.experimental_connect_to_cluster(tpu)
    # tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
    
    print('TPU successfully initialized. Found TPU: ', tpu.master())
    print("Number of replicas:", strategy.num_replicas_in_sync)

except Exception as e:
    print(f"TPU initialization failed, this is the error: {e}")
    print("Falling back to default strategy (CPU/GPU).")
    strategy = tf.distribute.get_strategy()
    BATCH_SIZE = BATCH_SIZE_PER_REPLICA
# Out:
# --- Initializing TPU Strategy ---
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: local
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753708720.954783      10 service.cc:148] XLA service 0x5726980b8040 initialized for platform TPU (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753708720.954846      10 service.cc:156]   StreamExecutor device (0): TPU, 2a886c8
# I0000 00:00:1753708720.954850      10 service.cc:156]   StreamExecutor device (1): TPU, 2a886c8
# I0000 00:00:1753708720.954853      10 service.cc:156]   StreamExecutor device (2): TPU, 2a886c8
# I0000 00:00:1753708720.954856      10 service.cc:156]   StreamExecutor device (3): TPU, 2a886c8
# I0000 00:00:1753708720.954859      10 service.cc:156]   StreamExecutor device (4): TPU, 2a886c8
# I0000 00:00:1753708720.954861      10 service.cc:156]   StreamExecutor device (5): TPU, 2a886c8
# I0000 00:00:1753708720.954864      10 service.cc:156]   StreamExecutor device (6): TPU, 2a886c8
# I0000 00:00:1753708720.954867      10 service.cc:156]   StreamExecutor device (7): TPU, 2a886c8
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# TPU successfully initialized. Found TPU:
# Number of replicas: 8

# %%
BATCH_SIZE = BATCH_SIZE_PER_REPLICA * strategy.num_replicas_in_sync
print(f"Global batch size set to: {BATCH_SIZE}")
# Out:
# Global batch size set to: 256

# %%
print("\nLoading all compressed features")

train_data = np.load(TRAIN_DATA_PATH)
val_data = np.load(VAL_DATA_PATH)
test_data = np.load(TEST_DATA_PATH)

# Access the arrays by the keys we used when saving ('x' and 'y')
X_train, y_train = train_data['x'], train_data['y']
X_val, y_val = val_data['x'], val_data['y']
X_test, y_test = test_data['x'], test_data['y']


print("All compressed data loaded successfully.")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# Loading all compressed features
# All compressed data loaded successfully.
# X_train shape: (33945, 150, 768)
# y_train shape: (33945, 6)

# %%
# Remove the last column ('NoStutter') from the labels
y_train = y_train[:, :-1]
y_val = y_val[:, :-1]
y_test = y_test[:, :-1]

# Filter out samples that now have NO labels
train_indices = np.where(y_train.sum(axis=1) > 0)[0]
val_indices = np.where(y_val.sum(axis=1) > 0)[0]
test_indices = np.where(y_test.sum(axis=1) > 0)[0]

X_train, y_train = X_train[train_indices], y_train[train_indices]
X_val, y_val = X_val[val_indices], y_val[val_indices]
X_test, y_test = X_test[test_indices], y_test[test_indices]

print("Data loaded and modified successfully.")
print(f"New X_train shape: {X_train.shape}")
print(f"New X_test shape: {X_test.shape}")
print(f"New X_val shape: {X_val.shape}")
# Out:
# Data loaded and modified successfully.
# New X_train shape: (29783, 150, 768)
# New X_test shape: (3906, 150, 768)
# New X_val shape: (3676, 150, 768)

# %%
print("\n Verifying final training set distribution after augmentation")

final_train_labels_df = pd.DataFrame(y_train, columns=LABEL_COLS)

print("Final distribution of labels in the training set (including augmented samples):")
print(final_train_labels_df.sum().sort_values(ascending=False))
# Out:
#  Verifying final training set distribution after augmentation
# Final distribution of labels in the training set (including augmented samples):
# Block           10848
# Interjection    10824
# Prolongation    10800
# SoundRep        10576
# WordRep         10569
# dtype: int64

# %%
print("\nBuilding tf.data pipeline")

def prepare_dataset(X, y, shuffle=False, drop_remainder = False):
    ds = tf.data.Dataset.from_tensor_slices((X, y))
    ds = ds.cache()
    if shuffle:
        ds = ds.shuffle(buffer_size=2048)
    ds = ds.batch(BATCH_SIZE, drop_remainder=drop_remainder)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

train_dataset = prepare_dataset(X_train, y_train, shuffle=True, drop_remainder=True)
val_dataset = prepare_dataset(X_val, y_val, shuffle=False, drop_remainder=True)
test_dataset = prepare_dataset(X_test, y_test, shuffle=False, drop_remainder=True)
print("Datasets created successfully.")
# Out:
# Building tf.data pipeline
# Datasets created successfully.

# %%
with strategy.scope():
    print("\nBuilding StutterFold Model")

    # This function for Module 1 remains unchanged
    def conformer_block(x, num_heads=4, ff_dim=128, dropout=0.1):
        # Convolution Module
        x_conv = layers.LayerNormalization()(x)
        x_conv = layers.Conv1D(filters=EMBEDDING_DIM * 2, kernel_size=1, activation="relu")(x_conv)
        x_conv = layers.DepthwiseConv1D(kernel_size=3, padding="same")(x_conv)
        x_conv = layers.BatchNormalization()(x_conv)
        x_conv = layers.Activation("swish")(x_conv)
        x_conv = layers.Conv1D(filters=EMBEDDING_DIM, kernel_size=1)(x_conv)
        x_conv = layers.Dropout(dropout)(x_conv)
        x = x + x_conv

        # Attention Module
        x_attn = layers.LayerNormalization()(x)
        x_attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=EMBEDDING_DIM // num_heads)(x_attn, x_attn)
        x_attn = layers.Dropout(dropout)(x_attn)
        x = x + x_attn

        # Feed Forward Module
        x_ff = layers.LayerNormalization()(x)
        x_ff = layers.Dense(ff_dim, activation="swish")(x_ff)
        x_ff = layers.Dropout(dropout)(x_ff)
        x_ff = layers.Dense(EMBEDDING_DIM)(x_ff)
        x = x + x_ff

        return x

    def build_stutterfold_model(input_shape, num_classes):
        inputs = layers.Input(shape=input_shape)
        x = inputs

        # Context Refinement using Conformer blocks
        x = conformer_block(x, num_heads=4, ff_dim=1028, dropout=0.5)
        x = conformer_block(x, num_heads=4, ff_dim=1028, dropout=0.5)
        # At this point, x is the enriched feature sequence (Batch, 150, 768)

        # Apply a classifier to every single time step independently
        x = layers.TimeDistributed(
            layers.Dense(num_classes, activation='sigmoid')
        )(x)
        # Now, x is the sequence of frame-wise predictions (Batch, 150, 5)
        
        # Pools the frame-wise predictions
        outputs = layers.GlobalAveragePooling1D()(x)
        # The final output shape is (Batch, 5)
        
        model = tf.keras.Model(inputs=inputs, outputs=outputs)
        
        return model

    model = build_stutterfold_model(input_shape=(MAX_SEQ_LEN, EMBEDDING_DIM), num_classes=NUM_CLASSES)

    optimizer = tf.keras.optimizers.AdamW(learning_rate=LEARNING_RATE, weight_decay=1e-4)
    
    model.compile(
        optimizer=optimizer,
        loss=tf.keras.losses.BinaryCrossentropy(label_smoothing=0.1),
        metrics=['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall'), tf.keras.metrics.AUC(name='auc_roc'), tf.keras.metrics.AUC(curve='PR', name='auc_pr')]
    )

model.summary()

print(f"LEARNING RATE: {LEARNING_RATE}")
print(f"BATCH SIZE: {BATCH_SIZE}")
# Out:
# Building StutterFold Model
# Model: "functional_4"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_4       │ (None, 150, 768)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ input_layer_4[0]… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_14 (Conv1D)  │ (None, 150, 1536) │  1,181,184 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv1d_7  │ (None, 150, 1536) │      6,144 │ conv1d_14[0][0]   │
# │ (DepthwiseConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 150, 1536) │      6,144 │ depthwise_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_7        │ (None, 150, 1536) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_15 (Conv1D)  │ (None, 150, 768)  │  1,180,416 │ activation_7[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_28          │ (None, 150, 768)  │          0 │ conv1d_15[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 150, 768)  │          0 │ input_layer_4[0]… │
# │                     │                   │            │ dropout_28[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_21[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 150, 768)  │  2,362,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_30          │ (None, 150, 768)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 150, 768)  │          0 │ add_21[0][0],     │
# │                     │                   │            │ dropout_30[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_22[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_18 (Dense)    │ (None, 150, 1028) │    790,532 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_31          │ (None, 150, 1028) │          0 │ dense_18[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_19 (Dense)    │ (None, 150, 768)  │    790,272 │ dropout_31[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 150, 768)  │          0 │ add_22[0][0],     │
# │                     │                   │            │ dense_19[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_23[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_16 (Conv1D)  │ (None, 150, 1536) │  1,181,184 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv1d_8  │ (None, 150, 1536) │      6,144 │ conv1d_16[0][0]   │
# │ (DepthwiseConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 150, 1536) │      6,144 │ depthwise_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_8        │ (None, 150, 1536) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_17 (Conv1D)  │ (None, 150, 768)  │  1,180,416 │ activation_8[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 150, 768)  │          0 │ conv1d_17[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_24 (Add)        │ (None, 150, 768)  │          0 │ add_23[0][0],     │
# │                     │                   │            │ dropout_32[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_24[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 150, 768)  │  2,362,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 150, 768)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_25 (Add)        │ (None, 150, 768)  │          0 │ add_24[0][0],     │
# │                     │                   │            │ dropout_34[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_25[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_20 (Dense)    │ (None, 150, 1028) │    790,532 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_35          │ (None, 150, 1028) │          0 │ dense_20[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_21 (Dense)    │ (None, 150, 768)  │    790,272 │ dropout_35[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_26 (Add)        │ (None, 150, 768)  │          0 │ add_25[0][0],     │
# │                     │                   │            │ dense_21[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ time_distributed_4  │ (None, 150, 5)    │      3,845 │ add_26[0][0]      │
# │ (TimeDistributed)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 5)         │          0 │ time_distributed… │
# │ (GlobalAveragePool… │                   │            │                   │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 12,647,181 (48.25 MB)
#  Trainable params: 12,641,037 (48.22 MB)
#  Non-trainable params: 6,144 (24.00 KB)
# LEARNING RATE: 1e-05
# BATCH SIZE: 256

# %%
checkpoint = tf.keras.callbacks.ModelCheckpoint(BEST_MODEL_PATH, monitor='val_auc_roc', mode='max', save_best_only=True, verbose=1)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc_roc', mode='max', patience=10, restore_best_weights=True, verbose=1)

# %%
print("\nStarting Training on TPU")
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[checkpoint, early_stopping]
)
# Out:
# Starting Training on TPU
# Epoch 1/400
# I0000 00:00:1753714769.446956      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:1448096973119004955
# I0000 00:00:1753714771.490296     936 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(7962799692443446766), session_name()
# I0000 00:00:1753714811.327043     936 tpu_compile_op_common.cc:245] Compilation of 7962799692443446766 with session name  took 39.836690538s and succeeded
# I0000 00:00:1753714811.404472     936 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(7962799692443446766), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_1448096973119004955", property.function_library_fingerprint = 15296873292404938570, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753714811.404514     936 tpu_compilation_cache_interface.cc:542] After adding entry for key 7962799692443446766 with session_name  cache is 12 entries (657208411 bytes),  marked for eviction 0 entries (0 bytes).
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3055 - auc_pr: 0.4611 - auc_roc: 0.6212 - loss: 0.6473 - precision: 0.5108 - recall: 0.1937
# I0000 00:00:1753714840.274296      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:8724509054082004994
# I0000 00:00:1753714840.834109     930 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(9876124762008582534), session_name()
# I0000 00:00:1753714847.058605     930 tpu_compile_op_common.cc:245] Compilation of 9876124762008582534 with session name  took 6.22444843s and succeeded
# I0000 00:00:1753714847.071715     930 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(9876124762008582534), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_8724509054082004994", property.function_library_fingerprint = 4136361764240164787, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753714847.071747     930 tpu_compilation_cache_interface.cc:542] After adding entry for key 9876124762008582534 with session_name  cache is 13 entries (679310010 bytes),  marked for eviction 0 entries (0 bytes).
# Epoch 1: val_auc_roc improved from -inf to 0.67036, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 101s 341ms/step - accuracy: 0.3053 - auc_pr: 0.4614 - auc_roc: 0.6214 - loss: 0.6472 - precision: 0.5113 - recall: 0.1938 - val_accuracy: 0.2330 - val_auc_pr: 0.5588 - val_auc_roc: 0.6704 - val_loss: 0.6602 - val_precision: 0.7256 - val_recall: 0.0671
# Epoch 2/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3050 - auc_pr: 0.5587 - auc_roc: 0.6845 - loss: 0.6213 - precision: 0.6261 - recall: 0.2852
# Epoch 2: val_auc_roc improved from 0.67036 to 0.68304, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 249ms/step - accuracy: 0.3051 - auc_pr: 0.5587 - auc_roc: 0.6845 - loss: 0.6213 - precision: 0.6261 - recall: 0.2853 - val_accuracy: 0.3086 - val_auc_pr: 0.5717 - val_auc_roc: 0.6830 - val_loss: 0.6481 - val_precision: 0.6932 - val_recall: 0.1414
# Epoch 3/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3238 - auc_pr: 0.5584 - auc_roc: 0.6827 - loss: 0.6226 - precision: 0.5942 - recall: 0.3136
# Epoch 3: val_auc_roc improved from 0.68304 to 0.70353, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 248ms/step - accuracy: 0.3239 - auc_pr: 0.5587 - auc_roc: 0.6830 - loss: 0.6225 - precision: 0.5945 - recall: 0.3138 - val_accuracy: 0.3133 - val_auc_pr: 0.6076 - val_auc_roc: 0.7035 - val_loss: 0.6336 - val_precision: 0.6845 - val_recall: 0.2503
# Epoch 4/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3435 - auc_pr: 0.5928 - auc_roc: 0.7100 - loss: 0.6077 - precision: 0.6320 - recall: 0.3595
# Epoch 4: val_auc_roc did not improve from 0.70353
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 238ms/step - accuracy: 0.3435 - auc_pr: 0.5930 - auc_roc: 0.7101 - loss: 0.6076 - precision: 0.6321 - recall: 0.3596 - val_accuracy: 0.3588 - val_auc_pr: 0.6141 - val_auc_roc: 0.7028 - val_loss: 0.6426 - val_precision: 0.6548 - val_recall: 0.3210
# Epoch 5/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3364 - auc_pr: 0.6142 - auc_roc: 0.7257 - loss: 0.6006 - precision: 0.6387 - recall: 0.3673
# Epoch 5: val_auc_roc did not improve from 0.70353
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 237ms/step - accuracy: 0.3366 - auc_pr: 0.6143 - auc_roc: 0.7258 - loss: 0.6005 - precision: 0.6389 - recall: 0.3675 - val_accuracy: 0.2790 - val_auc_pr: 0.6094 - val_auc_roc: 0.6980 - val_loss: 0.6593 - val_precision: 0.6019 - val_recall: 0.4170
# Epoch 6/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3730 - auc_pr: 0.6272 - auc_roc: 0.7375 - loss: 0.5928 - precision: 0.6507 - recall: 0.4025
# Epoch 6: val_auc_roc improved from 0.70353 to 0.70865, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 247ms/step - accuracy: 0.3730 - auc_pr: 0.6273 - auc_roc: 0.7375 - loss: 0.5927 - precision: 0.6508 - recall: 0.4026 - val_accuracy: 0.2623 - val_auc_pr: 0.6284 - val_auc_roc: 0.7086 - val_loss: 0.6725 - val_precision: 0.6128 - val_recall: 0.4478
# Epoch 7/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3571 - auc_pr: 0.6355 - auc_roc: 0.7396 - loss: 0.5919 - precision: 0.6506 - recall: 0.4100
# Epoch 7: val_auc_roc improved from 0.70865 to 0.71397, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 248ms/step - accuracy: 0.3573 - auc_pr: 0.6357 - auc_roc: 0.7397 - loss: 0.5918 - precision: 0.6508 - recall: 0.4101 - val_accuracy: 0.2606 - val_auc_pr: 0.6373 - val_auc_roc: 0.7140 - val_loss: 0.6786 - val_precision: 0.6132 - val_recall: 0.4778
# Epoch 8/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3917 - auc_pr: 0.6416 - auc_roc: 0.7473 - loss: 0.5827 - precision: 0.6611 - recall: 0.4248
# Epoch 8: val_auc_roc improved from 0.71397 to 0.72463, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 247ms/step - accuracy: 0.3916 - auc_pr: 0.6418 - auc_roc: 0.7474 - loss: 0.5827 - precision: 0.6612 - recall: 0.4249 - val_accuracy: 0.2673 - val_auc_pr: 0.6560 - val_auc_roc: 0.7246 - val_loss: 0.6685 - val_precision: 0.6262 - val_recall: 0.4888
# Epoch 9/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3935 - auc_pr: 0.6621 - auc_roc: 0.7539 - loss: 0.5781 - precision: 0.6787 - recall: 0.4394
# Epoch 9: val_auc_roc improved from 0.72463 to 0.72538, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 43s 258ms/step - accuracy: 0.3934 - auc_pr: 0.6622 - auc_roc: 0.7539 - loss: 0.5780 - precision: 0.6788 - recall: 0.4394 - val_accuracy: 0.2681 - val_auc_pr: 0.6551 - val_auc_roc: 0.7254 - val_loss: 0.6775 - val_precision: 0.6137 - val_recall: 0.5295
# Epoch 10/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4101 - auc_pr: 0.6760 - auc_roc: 0.7614 - loss: 0.5775 - precision: 0.6905 - recall: 0.4520
# Epoch 10: val_auc_roc did not improve from 0.72538
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 239ms/step - accuracy: 0.4099 - auc_pr: 0.6760 - auc_roc: 0.7615 - loss: 0.5774 - precision: 0.6905 - recall: 0.4520 - val_accuracy: 0.2603 - val_auc_pr: 0.6558 - val_auc_roc: 0.7248 - val_loss: 0.6946 - val_precision: 0.6059 - val_recall: 0.5531
# Epoch 11/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3737 - auc_pr: 0.6558 - auc_roc: 0.7601 - loss: 0.5781 - precision: 0.6743 - recall: 0.4501
# Epoch 11: val_auc_roc improved from 0.72538 to 0.72671, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 249ms/step - accuracy: 0.3739 - auc_pr: 0.6561 - auc_roc: 0.7602 - loss: 0.5780 - precision: 0.6744 - recall: 0.4502 - val_accuracy: 0.2670 - val_auc_pr: 0.6577 - val_auc_roc: 0.7267 - val_loss: 0.6976 - val_precision: 0.6224 - val_recall: 0.5145
# Epoch 12/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3931 - auc_pr: 0.6716 - auc_roc: 0.7652 - loss: 0.5733 - precision: 0.6737 - recall: 0.4582
# Epoch 12: val_auc_roc improved from 0.72671 to 0.74409, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 248ms/step - accuracy: 0.3932 - auc_pr: 0.6718 - auc_roc: 0.7653 - loss: 0.5732 - precision: 0.6739 - recall: 0.4583 - val_accuracy: 0.2941 - val_auc_pr: 0.6762 - val_auc_roc: 0.7441 - val_loss: 0.6691 - val_precision: 0.6252 - val_recall: 0.5565
# Epoch 13/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4047 - auc_pr: 0.6729 - auc_roc: 0.7687 - loss: 0.5728 - precision: 0.6820 - recall: 0.4639
# Epoch 13: val_auc_roc did not improve from 0.74409
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 238ms/step - accuracy: 0.4047 - auc_pr: 0.6731 - auc_roc: 0.7688 - loss: 0.5727 - precision: 0.6822 - recall: 0.4641 - val_accuracy: 0.2882 - val_auc_pr: 0.6636 - val_auc_roc: 0.7350 - val_loss: 0.6921 - val_precision: 0.6170 - val_recall: 0.5458
# Epoch 14/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.3849 - auc_pr: 0.6807 - auc_roc: 0.7746 - loss: 0.5680 - precision: 0.6875 - recall: 0.4663
# Epoch 14: val_auc_roc did not improve from 0.74409
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 238ms/step - accuracy: 0.3851 - auc_pr: 0.6808 - auc_roc: 0.7747 - loss: 0.5679 - precision: 0.6877 - recall: 0.4664 - val_accuracy: 0.3047 - val_auc_pr: 0.6662 - val_auc_roc: 0.7386 - val_loss: 0.6867 - val_precision: 0.6219 - val_recall: 0.5501
# Epoch 15/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4035 - auc_pr: 0.6979 - auc_roc: 0.7802 - loss: 0.5674 - precision: 0.7044 - recall: 0.4899
# Epoch 15: val_auc_roc did not improve from 0.74409
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 239ms/step - accuracy: 0.4036 - auc_pr: 0.6979 - auc_roc: 0.7802 - loss: 0.5673 - precision: 0.7044 - recall: 0.4899 - val_accuracy: 0.2988 - val_auc_pr: 0.6676 - val_auc_roc: 0.7393 - val_loss: 0.6945 - val_precision: 0.6129 - val_recall: 0.5795
# Epoch 16/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4206 - auc_pr: 0.6920 - auc_roc: 0.7830 - loss: 0.5611 - precision: 0.6900 - recall: 0.4897
# Epoch 16: val_auc_roc did not improve from 0.74409
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 40s 236ms/step - accuracy: 0.4206 - auc_pr: 0.6921 - auc_roc: 0.7831 - loss: 0.5610 - precision: 0.6901 - recall: 0.4898 - val_accuracy: 0.2893 - val_auc_pr: 0.6662 - val_auc_roc: 0.7375 - val_loss: 0.7054 - val_precision: 0.6012 - val_recall: 0.6019
# Epoch 17/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.3988 - auc_pr: 0.6985 - auc_roc: 0.7848 - loss: 0.5610 - precision: 0.6947 - recall: 0.4998
# Epoch 17: val_auc_roc did not improve from 0.74409
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 238ms/step - accuracy: 0.3989 - auc_pr: 0.6986 - auc_roc: 0.7848 - loss: 0.5609 - precision: 0.6948 - recall: 0.4999 - val_accuracy: 0.2874 - val_auc_pr: 0.6631 - val_auc_roc: 0.7361 - val_loss: 0.7148 - val_precision: 0.6094 - val_recall: 0.5761
# Epoch 18/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4043 - auc_pr: 0.6997 - auc_roc: 0.7901 - loss: 0.5564 - precision: 0.6954 - recall: 0.4993
# Epoch 18: val_auc_roc did not improve from 0.74409
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 251ms/step - accuracy: 0.4044 - auc_pr: 0.6999 - auc_roc: 0.7902 - loss: 0.5563 - precision: 0.6956 - recall: 0.4994 - val_accuracy: 0.2832 - val_auc_pr: 0.6597 - val_auc_roc: 0.7335 - val_loss: 0.7292 - val_precision: 0.5989 - val_recall: 0.5923
# Epoch 19/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4164 - auc_pr: 0.7191 - auc_roc: 0.7977 - loss: 0.5519 - precision: 0.7157 - recall: 0.5079
# Epoch 19: val_auc_roc did not improve from 0.74409
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 40s 237ms/step - accuracy: 0.4165 - auc_pr: 0.7191 - auc_roc: 0.7977 - loss: 0.5519 - precision: 0.7157 - recall: 0.5080 - val_accuracy: 0.2952 - val_auc_pr: 0.6730 - val_auc_roc: 0.7429 - val_loss: 0.7131 - val_precision: 0.6144 - val_recall: 0.5958
# Epoch 20/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4501 - auc_pr: 0.7139 - auc_roc: 0.8024 - loss: 0.5485 - precision: 0.7099 - recall: 0.5125
# Epoch 20: val_auc_roc improved from 0.74409 to 0.74477, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 249ms/step - accuracy: 0.4499 - auc_pr: 0.7140 - auc_roc: 0.8024 - loss: 0.5485 - precision: 0.7099 - recall: 0.5126 - val_accuracy: 0.2966 - val_auc_pr: 0.6751 - val_auc_roc: 0.7448 - val_loss: 0.7182 - val_precision: 0.6046 - val_recall: 0.6205
# Epoch 21/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4184 - auc_pr: 0.7097 - auc_roc: 0.7944 - loss: 0.5548 - precision: 0.6917 - recall: 0.5130
# Epoch 21: val_auc_roc improved from 0.74477 to 0.75154, saving model to out_stFold/run3_simp.keras
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 249ms/step - accuracy: 0.4185 - auc_pr: 0.7099 - auc_roc: 0.7946 - loss: 0.5547 - precision: 0.6919 - recall: 0.5132 - val_accuracy: 0.3083 - val_auc_pr: 0.6827 - val_auc_roc: 0.7515 - val_loss: 0.7126 - val_precision: 0.6110 - val_recall: 0.6192
# Epoch 22/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4332 - auc_pr: 0.7207 - auc_roc: 0.7989 - loss: 0.5506 - precision: 0.7175 - recall: 0.5242
# Epoch 22: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 239ms/step - accuracy: 0.4332 - auc_pr: 0.7208 - auc_roc: 0.7990 - loss: 0.5505 - precision: 0.7175 - recall: 0.5243 - val_accuracy: 0.3044 - val_auc_pr: 0.6654 - val_auc_roc: 0.7381 - val_loss: 0.7384 - val_precision: 0.6093 - val_recall: 0.5882
# Epoch 23/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4441 - auc_pr: 0.7238 - auc_roc: 0.8056 - loss: 0.5440 - precision: 0.7070 - recall: 0.5400
# Epoch 23: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.4440 - auc_pr: 0.7239 - auc_roc: 0.8057 - loss: 0.5439 - precision: 0.7072 - recall: 0.5400 - val_accuracy: 0.2985 - val_auc_pr: 0.6713 - val_auc_roc: 0.7442 - val_loss: 0.7371 - val_precision: 0.6086 - val_recall: 0.6081
# Epoch 24/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4254 - auc_pr: 0.7255 - auc_roc: 0.8051 - loss: 0.5453 - precision: 0.7115 - recall: 0.5244
# Epoch 24: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 239ms/step - accuracy: 0.4255 - auc_pr: 0.7256 - auc_roc: 0.8052 - loss: 0.5453 - precision: 0.7117 - recall: 0.5246 - val_accuracy: 0.2893 - val_auc_pr: 0.6599 - val_auc_roc: 0.7353 - val_loss: 0.7561 - val_precision: 0.6031 - val_recall: 0.5954
# Epoch 25/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4231 - auc_pr: 0.7123 - auc_roc: 0.7965 - loss: 0.5528 - precision: 0.6908 - recall: 0.5224
# Epoch 25: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.4233 - auc_pr: 0.7125 - auc_roc: 0.7967 - loss: 0.5527 - precision: 0.6911 - recall: 0.5227 - val_accuracy: 0.3041 - val_auc_pr: 0.6671 - val_auc_roc: 0.7419 - val_loss: 0.7533 - val_precision: 0.6012 - val_recall: 0.6185
# Epoch 26/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4233 - auc_pr: 0.7417 - auc_roc: 0.8114 - loss: 0.5433 - precision: 0.7370 - recall: 0.5441
# Epoch 26: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 240ms/step - accuracy: 0.4234 - auc_pr: 0.7417 - auc_roc: 0.8115 - loss: 0.5432 - precision: 0.7369 - recall: 0.5442 - val_accuracy: 0.2913 - val_auc_pr: 0.6646 - val_auc_roc: 0.7390 - val_loss: 0.7617 - val_precision: 0.5991 - val_recall: 0.6136
# Epoch 27/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4367 - auc_pr: 0.7347 - auc_roc: 0.8153 - loss: 0.5366 - precision: 0.7138 - recall: 0.5433
# Epoch 27: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 42s 249ms/step - accuracy: 0.4368 - auc_pr: 0.7348 - auc_roc: 0.8154 - loss: 0.5366 - precision: 0.7140 - recall: 0.5435 - val_accuracy: 0.3055 - val_auc_pr: 0.6611 - val_auc_roc: 0.7387 - val_loss: 0.7593 - val_precision: 0.5957 - val_recall: 0.6245
# Epoch 28/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4234 - auc_pr: 0.7349 - auc_roc: 0.8113 - loss: 0.5405 - precision: 0.7210 - recall: 0.5452
# Epoch 28: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 239ms/step - accuracy: 0.4236 - auc_pr: 0.7350 - auc_roc: 0.8114 - loss: 0.5404 - precision: 0.7211 - recall: 0.5454 - val_accuracy: 0.3027 - val_auc_pr: 0.6687 - val_auc_roc: 0.7432 - val_loss: 0.7518 - val_precision: 0.6075 - val_recall: 0.6057
# Epoch 29/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4465 - auc_pr: 0.7429 - auc_roc: 0.8184 - loss: 0.5340 - precision: 0.7277 - recall: 0.5513
# Epoch 29: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 238ms/step - accuracy: 0.4465 - auc_pr: 0.7430 - auc_roc: 0.8185 - loss: 0.5339 - precision: 0.7277 - recall: 0.5514 - val_accuracy: 0.2977 - val_auc_pr: 0.6596 - val_auc_roc: 0.7379 - val_loss: 0.7740 - val_precision: 0.5970 - val_recall: 0.6135
# Epoch 30/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 63ms/step - accuracy: 0.4387 - auc_pr: 0.7446 - auc_roc: 0.8151 - loss: 0.5381 - precision: 0.7300 - recall: 0.5657
# Epoch 30: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 238ms/step - accuracy: 0.4388 - auc_pr: 0.7448 - auc_roc: 0.8153 - loss: 0.5380 - precision: 0.7301 - recall: 0.5658 - val_accuracy: 0.2988 - val_auc_pr: 0.6497 - val_auc_roc: 0.7320 - val_loss: 0.7995 - val_precision: 0.6039 - val_recall: 0.5867
# Epoch 31/400
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 0s 64ms/step - accuracy: 0.4405 - auc_pr: 0.7553 - auc_roc: 0.8246 - loss: 0.5307 - precision: 0.7343 - recall: 0.5608
# Epoch 31: val_auc_roc did not improve from 0.75154
# 116/116 ━━━━━━━━━━━━━━━━━━━━ 41s 239ms/step - accuracy: 0.4406 - auc_pr: 0.7554 - auc_roc: 0.8247 - loss: 0.5306 - precision: 0.7343 - recall: 0.5609 - val_accuracy: 0.3047 - val_auc_pr: 0.6512 - val_auc_roc: 0.7342 - val_loss: 0.7956 - val_precision: 0.6003 - val_recall: 0.6008
# Epoch 31: early stopping
# Restoring model weights from the end of the best epoch: 21.

# %%
# lr = 1e-5
from sklearn.metrics import multilabel_confusion_matrix, precision_recall_curve, average_precision_score
import itertools

print("\n--- Evaluating Model on the Test Set ---")
y_pred_probs = model.predict(test_dataset)
y_pred_binary = (y_pred_probs > THRESHOLD).astype(int)

num_predictions = len(y_pred_binary)
y_test_eval = y_test[:num_predictions]

print("\n--- Classification Report (5 Stuttering Classes) ---")
report = classification_report(y_test_eval, y_pred_binary, target_names=LABEL_COLS, zero_division=0)
print(report)
with open(OUTPUT_DIR / "classification_report.txt", "w") as f:
    f.write(report)

print("\n--- Generating plots for model training history... ---")
history_dict = history.history
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
fig.suptitle('Classifier Training History', fontsize=16)
ax1.plot(history_dict['loss'], 'o-', label='Train Loss')
ax1.plot(history_dict['val_loss'], 'o-', label='Validation Loss')
ax1.set_title('Binary Crossentropy Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.legend(); ax1.grid(True)
ax2.plot(history_dict['val_auc_roc'], 'o-', label='Validation ROC-AUC')
ax2.plot(history_dict['val_auc_pr'], 'o-', label='Validation PR-AUC')
ax2.set_title('Validation AUCs'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('AUC'); ax2.legend(); ax2.grid(True)
plt.savefig(OUTPUT_DIR / "training_history.png")
plt.show()
# Out:
# --- Evaluating Model on the Test Set ---
# I0000 00:00:1753710064.274295      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:15137824681334478618
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753710064.426246      10 meta_optimizer.cc:966] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_1/batch_normalization_1/Cast/ReadVariableOp.
# I0000 00:00:1753710064.682360     959 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(12178684937981929286), session_name()
# I0000 00:00:1753710069.634746     959 tpu_compile_op_common.cc:245] Compilation of 12178684937981929286 with session name  took 4.952310954s and succeeded
# I0000 00:00:1753710069.646073     959 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(12178684937981929286), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_15137824681334478618", property.function_library_fingerprint = 9171742768830456824, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753710069.646100     959 tpu_compilation_cache_interface.cc:542] After adding entry for key 12178684937981929286 with session_name  cache is 3 entries (152877587 bytes),  marked for eviction 0 entries (0 bytes).
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 228ms/step
#
# --- Classification Report (5 Stuttering Classes) ---
#               precision    recall  f1-score   support
#
# Prolongation       0.64      0.46      0.54      1335
#        Block       0.61      0.50      0.55      1982
#     SoundRep       0.56      0.45      0.50       886
#      WordRep       0.45      0.56      0.50       917
# Interjection       0.83      0.71      0.76      1833
#
#    micro avg       0.64      0.55      0.59      6953
#    macro avg       0.62      0.53      0.57      6953
# weighted avg       0.65      0.55      0.59      6953
#  samples avg       0.60      0.57      0.55      6953
#
#
# --- Generating plots for model training history... ---

# %%
# lr = 5e-6

print("\n--- Evaluating Model on the Test Set ---")
y_pred_probs = model.predict(test_dataset)
y_pred_binary = (y_pred_probs > THRESHOLD).astype(int)

num_predictions = len(y_pred_binary)
y_test_eval = y_test[:num_predictions]

print("\n--- Classification Report (5 Stuttering Classes) ---")
report = classification_report(y_test_eval, y_pred_binary, target_names=LABEL_COLS, zero_division=0)
print(report)
with open(OUTPUT_DIR / "classification_report.txt", "w") as f:
    f.write(report)

print("\n--- Generating plots for model training history... ---")
history_dict = history.history
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
fig.suptitle('Classifier Training History', fontsize=16)
ax1.plot(history_dict['loss'], 'o-', label='Train Loss')
ax1.plot(history_dict['val_loss'], 'o-', label='Validation Loss')
ax1.set_title('Binary Crossentropy Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.legend(); ax1.grid(True)
ax2.plot(history_dict['val_auc_roc'], 'o-', label='Validation ROC-AUC')
ax2.set_title('Validation AUCs'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('AUC'); ax2.legend(); ax2.grid(True)
plt.savefig(OUTPUT_DIR / "training_history.png")
plt.show()
# Out:
# --- Evaluating Model on the Test Set ---
# I0000 00:00:1753712014.795056      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:1570929014504549669
# E0000 00:00:1753712015.033181      10 meta_optimizer.cc:966] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_1_1/batch_normalization_2_1/Cast/ReadVariableOp.
# I0000 00:00:1753712015.385289     936 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(3793880763008902353), session_name()
# I0000 00:00:1753712020.825868     936 tpu_compile_op_common.cc:245] Compilation of 3793880763008902353 with session name  took 5.440519697s and succeeded
# I0000 00:00:1753712020.840898     936 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(3793880763008902353), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_1570929014504549669", property.function_library_fingerprint = 17894557765429992693, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753712020.840940     936 tpu_compilation_cache_interface.cc:542] After adding entry for key 3793880763008902353 with session_name  cache is 6 entries (305819486 bytes),  marked for eviction 0 entries (0 bytes).
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 13s 176ms/step
#
# --- Classification Report (5 Stuttering Classes) ---
#               precision    recall  f1-score   support
#
# Prolongation       0.60      0.54      0.57      1335
#        Block       0.59      0.63      0.61      1982
#     SoundRep       0.59      0.49      0.54       886
#      WordRep       0.49      0.50      0.50       917
# Interjection       0.85      0.68      0.75      1833
#
#    micro avg       0.64      0.59      0.61      6953
#    macro avg       0.62      0.57      0.59      6953
# weighted avg       0.65      0.59      0.61      6953
#  samples avg       0.61      0.61      0.57      6953
#
#
# --- Generating plots for model training history... ---

# %%
# simpler model, cnfmr:2, drpt:0.2->0.5

print("\n--- Evaluating Model on the Test Set ---")
y_pred_probs = model.predict(test_dataset)
y_pred_binary = (y_pred_probs > THRESHOLD).astype(int)

num_predictions = len(y_pred_binary)
y_test_eval = y_test[:num_predictions]

print("\n--- Classification Report (5 Stuttering Classes) ---")
report = classification_report(y_test_eval, y_pred_binary, target_names=LABEL_COLS, zero_division=0)
print(report)
with open(OUTPUT_DIR / "classification_report.txt", "w") as f:
    f.write(report)

print("\n--- Generating plots for model training history... ---")
history_dict = history.history
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
fig.suptitle('Classifier Training History', fontsize=16)
ax1.plot(history_dict['loss'], 'o-', label='Train Loss')
ax1.plot(history_dict['val_loss'], 'o-', label='Validation Loss')
ax1.set_title('Binary Crossentropy Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.legend(); ax1.grid(True)
ax2.plot(history_dict['val_auc_roc'], 'o-', label='Validation ROC-AUC')
ax2.set_title('Validation AUCs'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('AUC'); ax2.legend(); ax2.grid(True)
plt.savefig(OUTPUT_DIR / "training_history.png")
plt.show()
# Out:
# --- Evaluating Model on the Test Set ---
# I0000 00:00:1753716094.519891      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:13860112308638970903
# E0000 00:00:1753716094.687941      10 meta_optimizer.cc:966] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_4_1/batch_normalization_7_1/Cast/ReadVariableOp.
# I0000 00:00:1753716094.952533     970 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(17318489309628045171), session_name()
# I0000 00:00:1753716100.882277     970 tpu_compile_op_common.cc:245] Compilation of 17318489309628045171 with session name  took 5.929680297s and succeeded
# I0000 00:00:1753716100.899295     970 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(17318489309628045171), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_13860112308638970903", property.function_library_fingerprint = 2813338738363550229, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753716100.899334     970 tpu_compilation_cache_interface.cc:542] After adding entry for key 17318489309628045171 with session_name  cache is 14 entries (698733975 bytes),  marked for eviction 0 entries (0 bytes).
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 185ms/step
#
# --- Classification Report (5 Stuttering Classes) ---
#               precision    recall  f1-score   support
#
# Prolongation       0.60      0.52      0.56      1335
#        Block       0.59      0.70      0.64      1982
#     SoundRep       0.50      0.62      0.55       886
#      WordRep       0.52      0.46      0.49       917
# Interjection       0.79      0.77      0.78      1833
#
#    micro avg       0.62      0.64      0.63      6953
#    macro avg       0.60      0.61      0.60      6953
# weighted avg       0.62      0.64      0.63      6953
#  samples avg       0.62      0.66      0.60      6953
#
#
# --- Generating plots for model training history... ---

# %%
# simpler model, cnfmr:2->1, drpt:0.2->0.4

print("\n--- Evaluating Model on the Test Set ---")
y_pred_probs = model.predict(test_dataset)
y_pred_binary = (y_pred_probs > THRESHOLD).astype(int)

num_predictions = len(y_pred_binary)
y_test_eval = y_test[:num_predictions]

print("\n--- Classification Report (5 Stuttering Classes) ---")
report = classification_report(y_test_eval, y_pred_binary, target_names=LABEL_COLS, zero_division=0)
print(report)
with open(OUTPUT_DIR / "classification_report.txt", "w") as f:
    f.write(report)

print("\n--- Generating plots for model training history... ---")
history_dict = history.history
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
fig.suptitle('Classifier Training History', fontsize=16)
ax1.plot(history_dict['loss'], 'o-', label='Train Loss')
ax1.plot(history_dict['val_loss'], 'o-', label='Validation Loss')
ax1.set_title('Binary Crossentropy Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.legend(); ax1.grid(True)
ax2.plot(history_dict['val_auc_roc'], 'o-', label='Validation ROC-AUC')
ax2.set_title('Validation AUCs'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('AUC'); ax2.legend(); ax2.grid(True)
plt.savefig(OUTPUT_DIR / "training_history.png")
plt.show()
# Out:
# --- Evaluating Model on the Test Set ---
# I0000 00:00:1753713845.179571      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:13939341230016073719
# E0000 00:00:1753713845.316264      10 meta_optimizer.cc:966] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_2_1/batch_normalization_4_1/Cast/ReadVariableOp.
# I0000 00:00:1753713845.523974     919 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(15618928649506042626), session_name()
# I0000 00:00:1753713850.921977     919 tpu_compile_op_common.cc:245] Compilation of 15618928649506042626 with session name  took 5.397917984s and succeeded
# I0000 00:00:1753713850.934990     919 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(15618928649506042626), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_13939341230016073719", property.function_library_fingerprint = 10827470221299739814, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753713850.935019     919 tpu_compilation_cache_interface.cc:542] After adding entry for key 15618928649506042626 with session_name  cache is 9 entries (412250862 bytes),  marked for eviction 0 entries (0 bytes).
# 15/15 ━━━━━━━━━━━━━━━━━━━━ 12s 173ms/step
#
# --- Classification Report (5 Stuttering Classes) ---
#               precision    recall  f1-score   support
#
# Prolongation       0.69      0.40      0.51      1335
#        Block       0.62      0.42      0.50      1982
#     SoundRep       0.56      0.46      0.51       886
#      WordRep       0.47      0.56      0.51       917
# Interjection       0.86      0.66      0.75      1833
#
#    micro avg       0.66      0.50      0.57      6953
#    macro avg       0.64      0.50      0.56      6953
# weighted avg       0.67      0.50      0.57      6953
#  samples avg       0.57      0.51      0.50      6953
#
#
# --- Generating plots for model training history... ---
