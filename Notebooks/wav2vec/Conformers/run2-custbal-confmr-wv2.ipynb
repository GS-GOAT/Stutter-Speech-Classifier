# %%
import pandas as pd
import numpy as np
import tensorflow as tf
import matplotlib.pyplot as plt
from pathlib import Path
import os

from sklearn.metrics import classification_report
import tensorflow.keras.backend as K
from tensorflow.keras.callbacks import ReduceLROnPlateau
from tensorflow.keras import layers

# %%
# Config 
INPUT_DIR = Path("/kaggle/working/output_wav2vec_custom_augmented")
OUTPUT_DIR = Path("./output_confmr_lr2_class_tpu")
OUTPUT_DIR.mkdir(exist_ok=True)

MAX_SEQ_LEN = 150
EMBEDDING_DIM = 768
LABEL_COLS = ['Prolongation', 'Block', 'SoundRep', 'WordRep', 'Interjection']
NUM_CLASSES = len(LABEL_COLS)

BATCH_SIZE_PER_REPLICA = 16
EPOCHS = 400
LEARNING_RATE = 1e-5
THRESHOLD = 0.5

TRAIN_DATA_PATH = INPUT_DIR / "train_data.npz"
VAL_DATA_PATH = INPUT_DIR / "val_data.npz"
TEST_DATA_PATH = INPUT_DIR / "test_data.npz"
OUTPUT_DIR = Path("./")
BEST_MODEL_PATH = OUTPUT_DIR / "best_confmr_lr2_model.keras"

# %%
print("--- Initializing TPU Strategy ---")

try:
    tpu = tf.distribute.cluster_resolver.TPUClusterResolver.connect(tpu='local')
    # tf.config.experimental_connect_to_cluster(tpu)
    # tf.tpu.experimental.initialize_tpu_system(tpu)
    strategy = tf.distribute.TPUStrategy(tpu)
    
    print('TPU successfully initialized. Found TPU: ', tpu.master())
    BATCH_SIZE = BATCH_SIZE_PER_REPLICA * strategy.num_replicas_in_sync
    print(f"Global batch size set to: {BATCH_SIZE}")
    print("Number of replicas:", strategy.num_replicas_in_sync)

except Exception as e:
    print(f"TPU initialization failed, this is the error: {e}")
    print("Falling back to default strategy (CPU/GPU).")
    strategy = tf.distribute.get_strategy()
    BATCH_SIZE = BATCH_SIZE_PER_REPLICA
# Out:
# --- Initializing TPU Strategy ---
# INFO:tensorflow:Deallocate tpu buffers before initializing tpu system.
# INFO:tensorflow:Initializing the TPU system: local
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1753183729.178482      10 service.cc:148] XLA service 0x5c5026197d40 initialized for platform TPU (this does not guarantee that XLA will be used). Devices:
# I0000 00:00:1753183729.178528      10 service.cc:156]   StreamExecutor device (0): TPU, 2a886c8
# I0000 00:00:1753183729.178533      10 service.cc:156]   StreamExecutor device (1): TPU, 2a886c8
# I0000 00:00:1753183729.178536      10 service.cc:156]   StreamExecutor device (2): TPU, 2a886c8
# I0000 00:00:1753183729.178538      10 service.cc:156]   StreamExecutor device (3): TPU, 2a886c8
# I0000 00:00:1753183729.178541      10 service.cc:156]   StreamExecutor device (4): TPU, 2a886c8
# I0000 00:00:1753183729.178544      10 service.cc:156]   StreamExecutor device (5): TPU, 2a886c8
# I0000 00:00:1753183729.178546      10 service.cc:156]   StreamExecutor device (6): TPU, 2a886c8
# I0000 00:00:1753183729.178549      10 service.cc:156]   StreamExecutor device (7): TPU, 2a886c8
# INFO:tensorflow:Finished initializing TPU system.
# INFO:tensorflow:Found TPU system:
# INFO:tensorflow:*** Num TPU Cores: 8
# INFO:tensorflow:*** Num TPU Workers: 1
# INFO:tensorflow:*** Num TPU Cores Per Worker: 8
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:CPU:0, CPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:0, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:1, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:2, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:3, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:4, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:5, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:6, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU:7, TPU, 0, 0)
# INFO:tensorflow:*** Available Device: _DeviceAttributes(/job:localhost/replica:0/task:0/device:TPU_SYSTEM:0, TPU_SYSTEM, 0, 0)
# ✅ TPU successfully initialized. Found TPU:
# Global batch size set to: 128
# Number of replicas: 8

# %%
print("\nLoading all compressed features")

train_data = np.load(TRAIN_DATA_PATH)
val_data = np.load(VAL_DATA_PATH)
test_data = np.load(TEST_DATA_PATH)

# Access the arrays by the keys we used when saving ('x' and 'y')
X_train, y_train = train_data['x'], train_data['y']
X_val, y_val = val_data['x'], val_data['y']
X_test, y_test = test_data['x'], test_data['y']


print("All compressed data loaded successfully.")
print(f"X_train shape: {X_train.shape}")
print(f"y_train shape: {y_train.shape}")
# Out:
# Loading all compressed features
# All compressed data loaded successfully.
# X_train shape: (33043, 150, 768)
# y_train shape: (33043, 6)

# %%
# Remove the last column ('NoStutter') from the labels
y_train = y_train[:, :-1]
y_val = y_val[:, :-1]
y_test = y_test[:, :-1]

# Filter out samples that now have NO labels
train_indices = np.where(y_train.sum(axis=1) > 0)[0]
val_indices = np.where(y_val.sum(axis=1) > 0)[0]
test_indices = np.where(y_test.sum(axis=1) > 0)[0]

X_train, y_train = X_train[train_indices], y_train[train_indices]
X_val, y_val = X_val[val_indices], y_val[val_indices]
X_test, y_test = X_test[test_indices], y_test[test_indices]

print("Data loaded and modified successfully.")
print(f"New X_train shape: {X_train.shape}")
# Out:
# Data loaded and modified successfully.
# New X_train shape: (28881, 150, 768)

# %%
print("\n Verifying final training set distribution after augmentation")

final_train_labels_df = pd.DataFrame(y_train, columns=LABEL_COLS)

print("Final distribution of labels in the training set (including augmented samples):")
print(final_train_labels_df.sum().sort_values(ascending=False))
# Out:
#  Verifying final training set distribution after augmentation
# Final distribution of labels in the training set (including augmented samples):
# Block           10848
# Interjection    10824
# Prolongation    10800
# SoundRep        10203
# WordRep         10040
# dtype: int64

# %%
print("\nBuilding tf.data pipeline")

def prepare_dataset(X, y, shuffle=False):
    ds = tf.data.Dataset.from_tensor_slices((X, y))
    if shuffle:
        ds = ds.shuffle(buffer_size=2048)
    ds = ds.batch(BATCH_SIZE)
    ds = ds.prefetch(tf.data.AUTOTUNE)
    return ds

train_dataset = prepare_dataset(X_train, y_train, shuffle=True)
val_dataset = prepare_dataset(X_val, y_val)
test_dataset = prepare_dataset(X_test, y_test)
print("Datasets created successfully.")
# Out:
# Building tf.data pipeline
# Datasets created successfully.

# %%
with strategy.scope():
    print("\nBuilding Conformer Model")

    # Conformer Block 
    def conformer_block(x, num_heads=4, ff_dim=128, dropout=0.1):
        # Convolution Module
        x_conv = layers.LayerNormalization()(x)
        x_conv = layers.Conv1D(filters=EMBEDDING_DIM * 2, kernel_size=1, activation="relu")(x_conv)
        x_conv = layers.DepthwiseConv1D(kernel_size=3, padding="same")(x_conv)
        x_conv = layers.BatchNormalization()(x_conv)
        x_conv = layers.Activation("swish")(x_conv)
        x_conv = layers.Conv1D(filters=EMBEDDING_DIM, kernel_size=1)(x_conv)
        x_conv = layers.Dropout(dropout)(x_conv)
        x = x + x_conv # Residual connection

        # Attention Module
        x_attn = layers.LayerNormalization()(x)
        x_attn = layers.MultiHeadAttention(num_heads=num_heads, key_dim=EMBEDDING_DIM // num_heads)(x_attn, x_attn)
        x_attn = layers.Dropout(dropout)(x_attn)
        x = x + x_attn # Residual connection

        # Feed Forward Module
        x_ff = layers.LayerNormalization()(x)
        x_ff = layers.Dense(ff_dim, activation="swish")(x_ff)
        x_ff = layers.Dropout(dropout)(x_ff)
        x_ff = layers.Dense(EMBEDDING_DIM)(x_ff)
        x = x + x_ff # Residual connection

        return x

    def build_conformer_classifier(input_shape, num_classes):
        inputs = layers.Input(shape=input_shape)
        x = inputs

        # Applies Conformer blocks
        x = conformer_block(x, num_heads=4, ff_dim=256)
        x = conformer_block(x, num_heads=4, ff_dim=256)

        # Pool the sequence to a single vector
        x = layers.GlobalAveragePooling1D()(x)

        # Classifier head
        x = layers.Dense(128, activation='relu')(x)
        x = layers.Dropout(0.5)(x)
        outputs = layers.Dense(num_classes, activation='sigmoid')(x)

        model = tf.keras.Model(inputs=inputs, outputs=outputs)

        optimizer = tf.keras.optimizers.Adam(learning_rate=LEARNING_RATE, clipnorm=1.0)

        model.compile(
            optimizer=optimizer,
            loss='binary_crossentropy',
            metrics=['accuracy', tf.keras.metrics.Precision(name='precision'), tf.keras.metrics.Recall(name='recall'), tf.keras.metrics.AUC(name='auc', multi_label=True)]
        )
        return model

    model = build_conformer_classifier(input_shape=(MAX_SEQ_LEN, EMBEDDING_DIM), num_classes=NUM_CLASSES)

model.summary()

checkpoint = tf.keras.callbacks.ModelCheckpoint(BEST_MODEL_PATH, monitor='val_auc', mode='max', save_best_only=True, verbose=1)
early_stopping = tf.keras.callbacks.EarlyStopping(monitor='val_auc', mode='max', patience=10, restore_best_weights=True)


print(f"LEARNING RATE: {LEARNING_RATE}")
print(f"BATCH SIZE: {BATCH_SIZE}")
# Out:
# Building Conformer Model
# Model: "functional_6"
# ┏━━━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┳━━━━━━━━━━━━┳━━━━━━━━━━━━━━━━━━━┓
# ┃ Layer (type)        ┃ Output Shape      ┃    Param # ┃ Connected to      ┃
# ┡━━━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━╇━━━━━━━━━━━━╇━━━━━━━━━━━━━━━━━━━┩
# │ input_layer_6       │ (None, 150, 768)  │          0 │ -                 │
# │ (InputLayer)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ input_layer_6[0]… │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_8 (Conv1D)   │ (None, 150, 1536) │  1,181,184 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv1d_2  │ (None, 150, 1536) │      6,144 │ conv1d_8[0][0]    │
# │ (DepthwiseConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 150, 1536) │      6,144 │ depthwise_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_2        │ (None, 150, 1536) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_9 (Conv1D)   │ (None, 150, 768)  │  1,180,416 │ activation_2[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_32          │ (None, 150, 768)  │          0 │ conv1d_9[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_18 (Add)        │ (None, 150, 768)  │          0 │ input_layer_6[0]… │
# │                     │                   │            │ dropout_32[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_18[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 150, 768)  │  2,362,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_34          │ (None, 150, 768)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_19 (Add)        │ (None, 150, 768)  │          0 │ add_18[0][0],     │
# │                     │                   │            │ dropout_34[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_19[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_28 (Dense)    │ (None, 150, 256)  │    196,864 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_35          │ (None, 150, 256)  │          0 │ dense_28[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_29 (Dense)    │ (None, 150, 768)  │    197,376 │ dropout_35[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_20 (Add)        │ (None, 150, 768)  │          0 │ add_19[0][0],     │
# │                     │                   │            │ dense_29[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_20[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_10 (Conv1D)  │ (None, 150, 1536) │  1,181,184 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ depthwise_conv1d_3  │ (None, 150, 1536) │      6,144 │ conv1d_10[0][0]   │
# │ (DepthwiseConv1D)   │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ batch_normalizatio… │ (None, 150, 1536) │      6,144 │ depthwise_conv1d… │
# │ (BatchNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ activation_3        │ (None, 150, 1536) │          0 │ batch_normalizat… │
# │ (Activation)        │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ conv1d_11 (Conv1D)  │ (None, 150, 768)  │  1,180,416 │ activation_3[0][… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_36          │ (None, 150, 768)  │          0 │ conv1d_11[0][0]   │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_21 (Add)        │ (None, 150, 768)  │          0 │ add_20[0][0],     │
# │                     │                   │            │ dropout_36[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_21[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ multi_head_attenti… │ (None, 150, 768)  │  2,362,368 │ layer_normalizat… │
# │ (MultiHeadAttentio… │                   │            │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_38          │ (None, 150, 768)  │          0 │ multi_head_atten… │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_22 (Add)        │ (None, 150, 768)  │          0 │ add_21[0][0],     │
# │                     │                   │            │ dropout_38[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ layer_normalizatio… │ (None, 150, 768)  │      1,536 │ add_22[0][0]      │
# │ (LayerNormalizatio… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_30 (Dense)    │ (None, 150, 256)  │    196,864 │ layer_normalizat… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_39          │ (None, 150, 256)  │          0 │ dense_30[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_31 (Dense)    │ (None, 150, 768)  │    197,376 │ dropout_39[0][0]  │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ add_23 (Add)        │ (None, 150, 768)  │          0 │ add_22[0][0],     │
# │                     │                   │            │ dense_31[0][0]    │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ global_average_poo… │ (None, 768)       │          0 │ add_23[0][0]      │
# │ (GlobalAveragePool… │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_32 (Dense)    │ (None, 128)       │     98,432 │ global_average_p… │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dropout_40          │ (None, 128)       │          0 │ dense_32[0][0]    │
# │ (Dropout)           │                   │            │                   │
# ├─────────────────────┼───────────────────┼────────────┼───────────────────┤
# │ dense_33 (Dense)    │ (None, 5)         │        645 │ dropout_40[0][0]  │
# └─────────────────────┴───────────────────┴────────────┴───────────────────┘
#  Total params: 10,369,285 (39.56 MB)
#  Trainable params: 10,363,141 (39.53 MB)
#  Non-trainable params: 6,144 (24.00 KB)
# LEARNING RATE: 1e-05
# BATCH SIZE: 128

# %%
reduce_lr_on_plateau = ReduceLROnPlateau(
    monitor='val_loss', 
    factor=0.5, 
    patience=2, 
    verbose=1,
    min_lr=1e-7
)

# %%
print("\nStarting Training on TPU")
history = model.fit(
    train_dataset,
    epochs=EPOCHS,
    validation_data=val_dataset,
    callbacks=[checkpoint, early_stopping, reduce_lr_on_plateau]
)
# Out:
# Starting Training on TPU
# Epoch 1/400
# I0000 00:00:1753209824.621928      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:3316331056252985050
# I0000 00:00:1753209826.417277     829 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(7510495391617258482), session_name()
# I0000 00:00:1753209845.444017     829 tpu_compile_op_common.cc:245] Compilation of 7510495391617258482 with session name  took 19.026243732s and succeeded
# I0000 00:00:1753209845.510511     829 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(7510495391617258482), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_3316331056252985050", property.function_library_fingerprint = 8731822837810700183, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "16,150,768,;16,5,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753209845.510573     829 tpu_compilation_cache_interface.cc:542] After adding entry for key 7510495391617258482 with session_name  cache is 31 entries (754101983 bytes),  marked for eviction 0 entries (0 bytes).
# 224/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.2666 - auc: 0.5854 - loss: 0.6530 - precision: 0.4790 - recall: 0.2741
# I0000 00:00:1753209856.514955     755 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(9253585882698216462), session_name()
# I0000 00:00:1753209874.913195     755 tpu_compile_op_common.cc:245] Compilation of 9253585882698216462 with session name  took 18.398145103s and succeeded
# I0000 00:00:1753209874.972335     755 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(9253585882698216462), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_3316331056252985050", property.function_library_fingerprint = 8731822837810700183, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "11,150,768,;11,5,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753209874.972384     755 tpu_compilation_cache_interface.cc:542] After adding entry for key 9253585882698216462 with session_name  cache is 32 entries (836820963 bytes),  marked for eviction 0 entries (0 bytes).
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 131ms/step - accuracy: 0.2667 - auc: 0.5858 - loss: 0.6528 - precision: 0.4795 - recall: 0.2740
# I0000 00:00:1753209892.634964      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:15485787925305041646
# I0000 00:00:1753209893.145510     814 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(11801448544437551336), session_name()
# I0000 00:00:1753209895.080051     814 tpu_compile_op_common.cc:245] Compilation of 11801448544437551336 with session name  took 1.934476133s and succeeded
# I0000 00:00:1753209895.086920     814 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(11801448544437551336), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_15485787925305041646", property.function_library_fingerprint = 8927255926210524265, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "16,150,768,;16,5,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753209895.086951     814 tpu_compilation_cache_interface.cc:542] After adding entry for key 11801448544437551336 with session_name  cache is 33 entries (848792744 bytes),  marked for eviction 0 entries (0 bytes).
# Epoch 1: val_auc improved from -inf to 0.66267, saving model to best_confmr_lr2_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 91s 230ms/step - accuracy: 0.2667 - auc: 0.5859 - loss: 0.6528 - precision: 0.4797 - recall: 0.2740 - val_accuracy: 0.1987 - val_auc: 0.6627 - val_loss: 0.6525 - val_precision: 0.5253 - val_recall: 0.1675 - learning_rate: 1.0000e-05
# Epoch 2/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 47ms/step - accuracy: 0.3186 - auc: 0.6748 - loss: 0.6063 - precision: 0.5955 - recall: 0.3394
# Epoch 2: val_auc improved from 0.66267 to 0.70011, saving model to best_confmr_lr2_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 43s 131ms/step - accuracy: 0.3186 - auc: 0.6748 - loss: 0.6063 - precision: 0.5955 - recall: 0.3394 - val_accuracy: 0.2177 - val_auc: 0.7001 - val_loss: 0.6516 - val_precision: 0.5029 - val_recall: 0.2786 - learning_rate: 1.0000e-05
# Epoch 3/400
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3371 - auc: 0.6862 - loss: 0.6009 - precision: 0.6042 - recall: 0.3719
# Epoch 3: val_auc improved from 0.70011 to 0.71474, saving model to best_confmr_lr2_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 42s 128ms/step - accuracy: 0.3371 - auc: 0.6863 - loss: 0.6008 - precision: 0.6043 - recall: 0.3721 - val_accuracy: 0.2287 - val_auc: 0.7147 - val_loss: 0.6199 - val_precision: 0.5744 - val_recall: 0.4662 - learning_rate: 1.0000e-05
# Epoch 4/400
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3458 - auc: 0.6958 - loss: 0.5938 - precision: 0.6126 - recall: 0.4009
# Epoch 4: val_auc improved from 0.71474 to 0.72412, saving model to best_confmr_lr2_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 42s 126ms/step - accuracy: 0.3458 - auc: 0.6960 - loss: 0.5937 - precision: 0.6129 - recall: 0.4011 - val_accuracy: 0.2366 - val_auc: 0.7241 - val_loss: 0.6292 - val_precision: 0.5601 - val_recall: 0.4388 - learning_rate: 1.0000e-05
# Epoch 5/400
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 46ms/step - accuracy: 0.3710 - auc: 0.7187 - loss: 0.5774 - precision: 0.6379 - recall: 0.4427
# Epoch 5: val_auc improved from 0.72412 to 0.72636, saving model to best_confmr_lr2_model.keras
#
# Epoch 5: ReduceLROnPlateau reducing learning rate to 4.999999873689376e-06.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 41s 125ms/step - accuracy: 0.3710 - auc: 0.7189 - loss: 0.5772 - precision: 0.6380 - recall: 0.4428 - val_accuracy: 0.2382 - val_auc: 0.7264 - val_loss: 0.6267 - val_precision: 0.5796 - val_recall: 0.4485 - learning_rate: 1.0000e-05
# Epoch 6/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3689 - auc: 0.7334 - loss: 0.5670 - precision: 0.6504 - recall: 0.4570
# Epoch 6: val_auc improved from 0.72636 to 0.72931, saving model to best_confmr_lr2_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 42s 128ms/step - accuracy: 0.3690 - auc: 0.7335 - loss: 0.5670 - precision: 0.6504 - recall: 0.4571 - val_accuracy: 0.2382 - val_auc: 0.7293 - val_loss: 0.6139 - val_precision: 0.5878 - val_recall: 0.4638 - learning_rate: 5.0000e-06
# Epoch 7/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3743 - auc: 0.7390 - loss: 0.5636 - precision: 0.6497 - recall: 0.4734
# Epoch 7: val_auc improved from 0.72931 to 0.73074, saving model to best_confmr_lr2_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 41s 124ms/step - accuracy: 0.3743 - auc: 0.7391 - loss: 0.5636 - precision: 0.6497 - recall: 0.4734 - val_accuracy: 0.2366 - val_auc: 0.7307 - val_loss: 0.6144 - val_precision: 0.5901 - val_recall: 0.4718 - learning_rate: 5.0000e-06
# Epoch 8/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3797 - auc: 0.7432 - loss: 0.5589 - precision: 0.6470 - recall: 0.4758
# Epoch 8: val_auc did not improve from 0.73074
#
# Epoch 8: ReduceLROnPlateau reducing learning rate to 2.499999936844688e-06.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 40s 121ms/step - accuracy: 0.3798 - auc: 0.7432 - loss: 0.5589 - precision: 0.6471 - recall: 0.4759 - val_accuracy: 0.2287 - val_auc: 0.7299 - val_loss: 0.6249 - val_precision: 0.5830 - val_recall: 0.4581 - learning_rate: 5.0000e-06
# Epoch 9/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3913 - auc: 0.7538 - loss: 0.5517 - precision: 0.6558 - recall: 0.4740
# Epoch 9: val_auc improved from 0.73074 to 0.73190, saving model to best_confmr_lr2_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 42s 126ms/step - accuracy: 0.3913 - auc: 0.7538 - loss: 0.5517 - precision: 0.6559 - recall: 0.4741 - val_accuracy: 0.2760 - val_auc: 0.7319 - val_loss: 0.5879 - val_precision: 0.6189 - val_recall: 0.4968 - learning_rate: 2.5000e-06
# Epoch 10/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3860 - auc: 0.7524 - loss: 0.5503 - precision: 0.6609 - recall: 0.4885
# Epoch 10: val_auc improved from 0.73190 to 0.73246, saving model to best_confmr_lr2_model.keras
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 44s 128ms/step - accuracy: 0.3861 - auc: 0.7524 - loss: 0.5502 - precision: 0.6610 - recall: 0.4885 - val_accuracy: 0.2666 - val_auc: 0.7325 - val_loss: 0.5906 - val_precision: 0.6163 - val_recall: 0.4928 - learning_rate: 2.5000e-06
# Epoch 11/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.4153 - auc: 0.7730 - loss: 0.5324 - precision: 0.6731 - recall: 0.5131
# Epoch 11: val_auc improved from 0.73246 to 0.73268, saving model to best_confmr_lr2_model.keras
#
# Epoch 11: ReduceLROnPlateau reducing learning rate to 1.249999968422344e-06.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 42s 129ms/step - accuracy: 0.4152 - auc: 0.7730 - loss: 0.5324 - precision: 0.6731 - recall: 0.5131 - val_accuracy: 0.2524 - val_auc: 0.7327 - val_loss: 0.6057 - val_precision: 0.6000 - val_recall: 0.4855 - learning_rate: 2.5000e-06
# Epoch 12/400
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3970 - auc: 0.7715 - loss: 0.5362 - precision: 0.6718 - recall: 0.5004
# Epoch 12: val_auc did not improve from 0.73268
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 40s 120ms/step - accuracy: 0.3971 - auc: 0.7715 - loss: 0.5362 - precision: 0.6719 - recall: 0.5005 - val_accuracy: 0.2492 - val_auc: 0.7297 - val_loss: 0.6084 - val_precision: 0.6021 - val_recall: 0.4654 - learning_rate: 1.2500e-06
# Epoch 13/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4102 - auc: 0.7579 - loss: 0.5488 - precision: 0.6653 - recall: 0.4817
# Epoch 13: val_auc did not improve from 0.73268
#
# Epoch 13: ReduceLROnPlateau reducing learning rate to 6.24999984211172e-07.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 41s 122ms/step - accuracy: 0.4102 - auc: 0.7580 - loss: 0.5488 - precision: 0.6654 - recall: 0.4818 - val_accuracy: 0.2555 - val_auc: 0.7302 - val_loss: 0.6002 - val_precision: 0.6112 - val_recall: 0.4823 - learning_rate: 1.2500e-06
# Epoch 14/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 50ms/step - accuracy: 0.3959 - auc: 0.7630 - loss: 0.5464 - precision: 0.6780 - recall: 0.4944
# Epoch 14: val_auc did not improve from 0.73268
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 41s 123ms/step - accuracy: 0.3960 - auc: 0.7631 - loss: 0.5464 - precision: 0.6780 - recall: 0.4945 - val_accuracy: 0.2461 - val_auc: 0.7281 - val_loss: 0.6096 - val_precision: 0.6025 - val_recall: 0.4638 - learning_rate: 6.2500e-07
# Epoch 15/400
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 51ms/step - accuracy: 0.4015 - auc: 0.7705 - loss: 0.5357 - precision: 0.6843 - recall: 0.5037
# Epoch 15: val_auc did not improve from 0.73268
#
# Epoch 15: ReduceLROnPlateau reducing learning rate to 3.12499992105586e-07.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 41s 125ms/step - accuracy: 0.4015 - auc: 0.7705 - loss: 0.5356 - precision: 0.6843 - recall: 0.5038 - val_accuracy: 0.2492 - val_auc: 0.7289 - val_loss: 0.6076 - val_precision: 0.6012 - val_recall: 0.4662 - learning_rate: 6.2500e-07
# Epoch 16/400
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4009 - auc: 0.7658 - loss: 0.5403 - precision: 0.6603 - recall: 0.4832
# Epoch 16: val_auc did not improve from 0.73268
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 41s 122ms/step - accuracy: 0.4010 - auc: 0.7659 - loss: 0.5402 - precision: 0.6605 - recall: 0.4835 - val_accuracy: 0.2587 - val_auc: 0.7304 - val_loss: 0.5908 - val_precision: 0.6212 - val_recall: 0.4807 - learning_rate: 3.1250e-07
# Epoch 17/400
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3839 - auc: 0.7595 - loss: 0.5468 - precision: 0.6608 - recall: 0.4882
# Epoch 17: val_auc did not improve from 0.73268
#
# Epoch 17: ReduceLROnPlateau reducing learning rate to 1.56249996052793e-07.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 42s 128ms/step - accuracy: 0.3841 - auc: 0.7596 - loss: 0.5467 - precision: 0.6610 - recall: 0.4885 - val_accuracy: 0.2571 - val_auc: 0.7301 - val_loss: 0.5935 - val_precision: 0.6152 - val_recall: 0.4815 - learning_rate: 3.1250e-07
# Epoch 18/400
# 225/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3902 - auc: 0.7728 - loss: 0.5386 - precision: 0.6844 - recall: 0.4995
# Epoch 18: val_auc did not improve from 0.73268
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 41s 123ms/step - accuracy: 0.3903 - auc: 0.7728 - loss: 0.5386 - precision: 0.6844 - recall: 0.4996 - val_accuracy: 0.2760 - val_auc: 0.7319 - val_loss: 0.5752 - val_precision: 0.6391 - val_recall: 0.5032 - learning_rate: 1.5625e-07
# Epoch 19/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.3901 - auc: 0.7648 - loss: 0.5388 - precision: 0.6668 - recall: 0.4863
# Epoch 19: val_auc did not improve from 0.73268
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 41s 123ms/step - accuracy: 0.3902 - auc: 0.7649 - loss: 0.5388 - precision: 0.6668 - recall: 0.4864 - val_accuracy: 0.2713 - val_auc: 0.7316 - val_loss: 0.5772 - val_precision: 0.6362 - val_recall: 0.4984 - learning_rate: 1.5625e-07
# Epoch 20/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 49ms/step - accuracy: 0.4018 - auc: 0.7646 - loss: 0.5426 - precision: 0.6709 - recall: 0.4975
# Epoch 20: val_auc did not improve from 0.73268
#
# Epoch 20: ReduceLROnPlateau reducing learning rate to 1e-07.
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 41s 121ms/step - accuracy: 0.4018 - auc: 0.7646 - loss: 0.5426 - precision: 0.6710 - recall: 0.4975 - val_accuracy: 0.2713 - val_auc: 0.7318 - val_loss: 0.5771 - val_precision: 0.6356 - val_recall: 0.5000 - learning_rate: 1.5625e-07
# Epoch 21/400
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 0s 48ms/step - accuracy: 0.3855 - auc: 0.7636 - loss: 0.5469 - precision: 0.6788 - recall: 0.4872
# Epoch 21: val_auc did not improve from 0.73268
# 226/226 ━━━━━━━━━━━━━━━━━━━━ 40s 121ms/step - accuracy: 0.3856 - auc: 0.7637 - loss: 0.5468 - precision: 0.6788 - recall: 0.4873 - val_accuracy: 0.2776 - val_auc: 0.7320 - val_loss: 0.5713 - val_precision: 0.6391 - val_recall: 0.5048 - learning_rate: 1.0000e-07

# %%
print("\nEvaluating Model on the Test Set")
y_pred_probs = model.predict(test_dataset)
y_pred = (y_pred_probs > THRESHOLD).astype(int)

num_predictions = len(y_pred)
report = classification_report(y_test[:num_predictions], y_pred, target_names=LABEL_COLS, zero_division=0)
print("\n Classification Report (5 Stuttering Classes) ")
print(report)
with open(OUTPUT_DIR / "classification_report.txt", "w") as f:
    f.write(report)

# --- Plotting History ---
print("\nGenerating plots for model training history")
history_dict = history.history
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
ax1.plot(history_dict['loss'], 'o-', label='Train Loss')
ax1.plot(history_dict['val_loss'], 'o-', label='Validation Loss')
ax1.set_title('Binary Crossentropy Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.legend(); ax1.grid(True)
ax2.plot(history_dict['val_auc'], 'o-', label='Validation AUC')
ax2.set_title('Validation AUC'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('AUC'); ax2.legend(); ax2.grid(True)
plt.savefig(OUTPUT_DIR / "training_history_1d_cnn_5_class_tpu.png")
plt.show()

print(f"\n--- Pipeline complete. All outputs saved in '{OUTPUT_DIR}' directory. ---")
# Out:
# Evaluating Model on the Test Set
# I0000 00:00:1753185620.842903      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:16901305469887961219
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1753185620.867360      10 meta_optimizer.cc:966] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_1/dense_1/BiasAdd/ReadVariableOp.
# I0000 00:00:1753185620.939810     801 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(5569639040946747444), session_name()
# I0000 00:00:1753185622.644527     801 tpu_compile_op_common.cc:245] Compilation of 5569639040946747444 with session name  took 1.704655914s and succeeded
# I0000 00:00:1753185622.647869     801 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(5569639040946747444), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_16901305469887961219", property.function_library_fingerprint = 3136207583786936660, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753185622.647897     801 tpu_compilation_cache_interface.cc:542] After adding entry for key 5569639040946747444 with session_name  cache is 4 entries (130726914 bytes),  marked for eviction 0 entries (0 bytes).
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 82ms/step
# I0000 00:00:1753185627.558726      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:4150484324106321972
# I0000 00:00:1753185627.806234     738 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(16983742599322048262), session_name()
# I0000 00:00:1753185629.211037     738 tpu_compile_op_common.cc:245] Compilation of 16983742599322048262 with session name  took 1.404754516s and succeeded
# I0000 00:00:1753185629.214057     738 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(16983742599322048262), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_4150484324106321972", property.function_library_fingerprint = 6734680035167650444, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "5,150,768,;5,5,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753185629.214085     738 tpu_compilation_cache_interface.cc:542] After adding entry for key 16983742599322048262 with session_name  cache is 5 entries (134939518 bytes),  marked for eviction 0 entries (0 bytes).
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 16s 184ms/step
#
#  Classification Report (5 Stuttering Classes)
#               precision    recall  f1-score   support
#
# Prolongation       0.61      0.52      0.56      2613
#        Block       0.61      0.51      0.56      3501
#     SoundRep       0.59      0.49      0.53      1891
#      WordRep       0.56      0.39      0.46      1742
# Interjection       0.87      0.61      0.71      3344
#
#    micro avg       0.66      0.52      0.58     13091
#    macro avg       0.65      0.50      0.57     13091
# weighted avg       0.67      0.52      0.58     13091
#  samples avg       0.62      0.54      0.54     13091
#
#
# Generating plots for model training history
# --- Pipeline complete. All outputs saved in 'output_conformer_training_tpu' directory. ---

# %%
from sklearn.metrics import multilabel_confusion_matrix, precision_recall_curve, average_precision_score
import itertools

print("\n--- Evaluating Model on the Test Set ---")
y_pred_probs = model.predict(test_dataset)
y_pred_binary = (y_pred_probs > THRESHOLD).astype(int)

num_predictions = len(y_pred_binary)
y_test_eval = y_test[:num_predictions]

print("\n--- Classification Report (5 Stuttering Classes) ---")
report = classification_report(y_test_eval, y_pred_binary, target_names=LABEL_COLS, zero_division=0)
print(report)
with open(OUTPUT_DIR / "classification_report.txt", "w") as f:
    f.write(report)

print("\n--- Generating plots for model training history... ---")
history_dict = history.history
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
fig.suptitle('Classifier Training History', fontsize=16)
ax1.plot(history_dict['loss'], 'o-', label='Train Loss')
ax1.plot(history_dict['val_loss'], 'o-', label='Validation Loss')
ax1.set_title('Binary Crossentropy Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.legend(); ax1.grid(True)
ax2.plot(history_dict['val_auc'], 'o-', label='Validation AUC')
ax2.set_title('Validation AUC'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('AUC'); ax2.legend(); ax2.grid(True)
plt.savefig(OUTPUT_DIR / "training_history.png")
plt.show()
# Out:
# --- Evaluating Model on the Test Set ---
# I0000 00:00:1753209558.047915      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:16486520658014281352
# E0000 00:00:1753209558.123601      10 meta_optimizer.cc:966] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_5_1/batch_normalization_4_1/Cast/ReadVariableOp.
# I0000 00:00:1753209558.287637     773 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(15060962088579803443), session_name()
# I0000 00:00:1753209559.720417     773 tpu_compile_op_common.cc:245] Compilation of 15060962088579803443 with session name  took 1.432700536s and succeeded
# I0000 00:00:1753209559.726181     773 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(15060962088579803443), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_16486520658014281352", property.function_library_fingerprint = 11273012821402104703, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753209559.726218     773 tpu_compilation_cache_interface.cc:542] After adding entry for key 15060962088579803443 with session_name  cache is 29 entries (661296682 bytes),  marked for eviction 0 entries (0 bytes).
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 95ms/step
# I0000 00:00:1753209565.726923      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:13579757836096463724
# I0000 00:00:1753209565.985334     797 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(2090804317232352023), session_name()
# I0000 00:00:1753209568.097986     797 tpu_compile_op_common.cc:245] Compilation of 2090804317232352023 with session name  took 2.112577512s and succeeded
# I0000 00:00:1753209568.104338     797 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(2090804317232352023), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_13579757836096463724", property.function_library_fingerprint = 9046158929247127201, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "5,150,768,;5,5,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753209568.104379     797 tpu_compilation_cache_interface.cc:542] After adding entry for key 2090804317232352023 with session_name  cache is 30 entries (671154676 bytes),  marked for eviction 0 entries (0 bytes).
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 18s 222ms/step
#
# --- Classification Report (5 Stuttering Classes) ---
#               precision    recall  f1-score   support
#
# Prolongation       0.64      0.52      0.57      2613
#        Block       0.62      0.48      0.54      3501
#     SoundRep       0.60      0.48      0.53      1891
#      WordRep       0.53      0.41      0.47      1742
# Interjection       0.77      0.75      0.76      3344
#
#    micro avg       0.66      0.55      0.60     13091
#    macro avg       0.63      0.53      0.57     13091
# weighted avg       0.65      0.55      0.59     13091
#  samples avg       0.63      0.56      0.56     13091
#
#
# --- Generating plots for model training history... ---

# %%
from sklearn.metrics import multilabel_confusion_matrix, precision_recall_curve, average_precision_score
import itertools

print("\n--- Evaluating Model on the Test Set ---")
y_pred_probs = model.predict(test_dataset)
y_pred_binary = (y_pred_probs > THRESHOLD).astype(int)

num_predictions = len(y_pred_binary)
y_test_eval = y_test[:num_predictions]

print("\n--- Classification Report (5 Stuttering Classes) ---")
report = classification_report(y_test_eval, y_pred_binary, target_names=LABEL_COLS, zero_division=0)
print(report)
with open(OUTPUT_DIR / "classification_report.txt", "w") as f:
    f.write(report)

print("\n--- Generating plots for model training history... ---")
history_dict = history.history
fig, (ax1, ax2) = plt.subplots(1, 2, figsize=(18, 7))
fig.suptitle('Classifier Training History', fontsize=16)
ax1.plot(history_dict['loss'], 'o-', label='Train Loss')
ax1.plot(history_dict['val_loss'], 'o-', label='Validation Loss')
ax1.set_title('Binary Crossentropy Loss'); ax1.set_xlabel('Epoch'); ax1.set_ylabel('Loss'); ax1.legend(); ax1.grid(True)
ax2.plot(history_dict['val_auc'], 'o-', label='Validation AUC')
ax2.set_title('Validation AUC'); ax2.set_xlabel('Epoch'); ax2.set_ylabel('AUC'); ax2.legend(); ax2.grid(True)
plt.savefig(OUTPUT_DIR / "training_history.png")
plt.show()


# print(f"\n--- Pipeline complete. All outputs saved in '{OUTPUT_DIR}' directory. ---")
# Out:
# --- Evaluating Model on the Test Set ---
# I0000 00:00:1753210736.465401      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:5867902572254916907
# E0000 00:00:1753210736.513371      10 meta_optimizer.cc:966] model_pruner failed: INVALID_ARGUMENT: Graph does not contain terminal node functional_6_1/batch_normalization_6_1/Cast/ReadVariableOp.
# I0000 00:00:1753210736.635636     780 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(17077238431838853193), session_name()
# I0000 00:00:1753210738.022924     780 tpu_compile_op_common.cc:245] Compilation of 17077238431838853193 with session name  took 1.387229644s and succeeded
# I0000 00:00:1753210738.028510     780 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(17077238431838853193), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_5867902572254916907", property.function_library_fingerprint = 10752152565366790531, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753210738.028541     780 tpu_compilation_cache_interface.cc:542] After adding entry for key 17077238431838853193 with session_name  cache is 34 entries (857495260 bytes),  marked for eviction 0 entries (0 bytes).
# 54/55 ━━━━━━━━━━━━━━━━━━━━ 0s 87ms/step
# I0000 00:00:1753210743.535748      10 encapsulate_tpu_computations_pass.cc:266] Subgraph fingerprint:7221451730374125248
# I0000 00:00:1753210743.773122     737 tpu_compilation_cache_interface.cc:442] TPU host compilation cache miss: cache_key(16020394749057512030), session_name()
# I0000 00:00:1753210745.897632     737 tpu_compile_op_common.cc:245] Compilation of 16020394749057512030 with session name  took 2.124442509s and succeeded
# I0000 00:00:1753210745.903295     737 tpu_compilation_cache_interface.cc:476] TPU host compilation cache: compilation complete for cache_key(16020394749057512030), session_name(), subgraph_key(std::string(property.function_name) = "cluster_one_step_on_data_distributed_7221451730374125248", property.function_library_fingerprint = 7351567605195667332, property.mlir_module_fingerprint = 0, property.num_replicas = 8, topology.chip_bounds().x = 2, topology.chip_bounds().y = 2, topology.chip_bounds().z = 1, topology.wrap().x = false, topology.wrap().y = false, topology.wrap().z = false, std::string(property.shapes_prefix) = "5,150,768,;5,5,;", property.guaranteed_constants_size = 0, embedding_partitions_fingerprint = "1688352644216761960")
# I0000 00:00:1753210745.903332     737 tpu_compilation_cache_interface.cc:542] After adding entry for key 16020394749057512030 with session_name  cache is 35 entries (867353302 bytes),  marked for eviction 0 entries (0 bytes).
# 55/55 ━━━━━━━━━━━━━━━━━━━━ 17s 213ms/step
#
# --- Classification Report (5 Stuttering Classes) ---
#               precision    recall  f1-score   support
#
# Prolongation       0.70      0.34      0.46      2613
#        Block       0.64      0.37      0.47      3501
#     SoundRep       0.60      0.45      0.51      1891
#      WordRep       0.46      0.61      0.52      1742
# Interjection       0.87      0.62      0.72      3344
#
#    micro avg       0.66      0.47      0.55     13091
#    macro avg       0.65      0.48      0.54     13091
# weighted avg       0.68      0.47      0.55     13091
#  samples avg       0.59      0.48      0.50     13091
#
#
# --- Generating plots for model training history... ---
